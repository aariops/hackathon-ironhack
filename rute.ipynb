# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("GENDER_EMP_05032020174140376.csv")
df
# Out:
#       COU         Country      IND                          Indicator    SEX  \
# 0     AUS       Australia  EMP15_U  Time spent in unpaid work, by sex    MEN
# 1     AUS       Australia  EMP15_U  Time spent in unpaid work, by sex  WOMEN
# 2     AUS       Australia  EMP15_P    Time spent in paid work, by sex    MEN
# 3     AUS       Australia  EMP15_P    Time spent in paid work, by sex  WOMEN
# 4     AUS       Australia  EMP15_T   Time spent in total work, by sex    MEN
# ..    ...             ...      ...                                ...    ...
# 199  OAVG  OECD - Average  EMP15_U  Time spent in unpaid work, by sex  WOMEN
# 200  OAVG  OECD - Average  EMP15_P    Time spent in paid work, by sex    MEN
# 201  OAVG  OECD - Average  EMP15_P    Time spent in paid work, by sex  WOMEN
# 202  OAVG  OECD - Average  EMP15_T   Time spent in total work, by sex    MEN
# 203  OAVG  OECD - Average  EMP15_T   Time spent in total work, by sex  WOMEN
#
# ...

# %%
df.dtypes
# Out:
# COU                       object
# Country                   object
# IND                       object
# Indicator                 object
# SEX                       object
# Sex                       object
# AGE                        int64
# Age Group                 object
# TIME                      object
# Time                      object
# Unit Code                 object
# Unit                      object
# PowerCode Code             int64
# PowerCode                 object
# Reference Period Code    float64
# Reference Period         float64
# Value                    float64
# Flag Codes               float64
# Flags                    float64
# dtype: object

# %%
df["Country"].unique()
# Out:
# array(['Australia', 'Austria', 'Belgium', 'Canada', 'Denmark', 'Finland',
#        'France', 'Germany', 'Greece', 'Hungary', 'Ireland', 'Italy',
#        'Japan', 'Korea', 'Mexico', 'Netherlands', 'New Zealand', 'Norway',
#        'Poland', 'Portugal', 'Spain', 'Sweden', 'Turkey',
#        'United Kingdom', 'United States', "China (People's Republic of)",
#        'Estonia', 'India', 'Latvia', 'Slovenia', 'South Africa',
#        'Luxembourg', 'Lithuania', 'OECD - Average'], dtype=object)

# %%
df["Country"].value_counts()
# Out:
# United States                   6
# China (People's Republic of)    6
# United Kingdom                  6
# Lithuania                       6
# Luxembourg                      6
# India                           6
# Estonia                         6
# Netherlands                     6
# Austria                         6
# Turkey                          6
# Portugal                        6
# South Africa                    6
# Germany                         6
# Slovenia                        6
# New Zealand                     6
# Hungary                         6
# Finland                         6
# OECD - Average                  6
# Ireland                         6
# Latvia                          6
# France                          6
# Australia                       6
# Poland                          6
# Spain                           6
# Greece                          6
# Canada                          6
# Denmark                         6
# ...

# %%
time = pd.read_csv("TIME_USE_05032020175543821.csv")
time
# Out:
#     LOCATION     Country DESC         Description    SEX    Sex    AGE    Age  \
# 0        AUS   Australia  UPW         Unpaid work  TOTAL  Total  15_64  15-64
# 1        AUS   Australia  UPW         Unpaid work  WOMEN  Women  15_64  15-64
# 2        AUS   Australia  UPW         Unpaid work    MEN    Men  15_64  15-64
# 3        AUT     Austria  UPW         Unpaid work  TOTAL  Total  15_64  15-64
# 4        AUT     Austria  UPW         Unpaid work  WOMEN  Women  15_64  15-64
# ..       ...         ...  ...                 ...    ...    ...    ...    ...
# 490      LUX  Luxembourg  PAW  Paid work or study  WOMEN  Women  15_64  15-64
# 491      LUX  Luxembourg  PAW  Paid work or study    MEN    Men  15_64  15-64
# 492      LTU   Lithuania  PAW  Paid work or study  TOTAL  Total  15_64  15-64
# 493      LTU   Lithuania  PAW  Paid work or study  WOMEN  Women  15_64  15-64
# 494      LTU   Lithuania  PAW  Paid work or study    MEN    Men  15_64  15-64
#
# ...
